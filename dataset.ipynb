# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("customer_churn_dataset-testing-master.csv")
df
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.shape
# Out:
# (64374, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64374 entries, 0 to 64373
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         64374 non-null  int64
#  1   Age                64374 non-null  int64
#  2   Gender             64374 non-null  str
#  3   Tenure             64374 non-null  int64
#  4   Usage Frequency    64374 non-null  int64
#  5   Support Calls      64374 non-null  int64
#  6   Payment Delay      64374 non-null  int64
#  7   Subscription Type  64374 non-null  str
#  8   Contract Length    64374 non-null  str
#  9   Total Spend        64374 non-null  int64
#  10  Last Interaction   64374 non-null  int64
#  11  Churn              64374 non-null  int64
# dtypes: int64(9), str(3)
# memory usage: 7.1 MB

# %%
df.describe()
# Out:
#          CustomerID           Age        Tenure  Usage Frequency  \
# count  64374.000000  64374.000000  64374.000000     64374.000000
# mean   32187.500000     41.970982     31.994827        15.080234
# std    18583.317451     13.924911     17.098234         8.816470
# min        1.000000     18.000000      1.000000         1.000000
# 25%    16094.250000     30.000000     18.000000         7.000000
# 50%    32187.500000     42.000000     33.000000        15.000000
# 75%    48280.750000     54.000000     47.000000        23.000000
# max    64374.000000     65.000000     60.000000        30.000000
#
#        Support Calls  Payment Delay   Total Spend  Last Interaction  \
# count   64374.000000   64374.000000  64374.000000      64374.000000
# mean        5.400690      17.133952    541.023379         15.498850
# std         3.114005       8.852211    260.874809          8.638436
# min         0.000000       0.000000    100.000000          1.000000
# ...

# %% [markdown]
# # Observation
# Dataset contains 64,374 records and 12 columns.
# Target variable is Churn.
# Dataset contains both numerical and categorical features.

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %% [markdown]
# # observation
# In this dataset there is no any missing value our dataset is ready for preprocessing

# %%
sns.countplot(x='Churn', data=df)
plt.show()

# %% [markdown]
# # Observation
# Analyze whether churn and non-churn customers are balanced.
# If imbalance exists, mention it.

# %%
df.drop("CustomerID", axis=1, inplace=True
        )

# %% [markdown]
# # Observation
# customerID has no predictive importance. Removed to improve model performance

# %%
le = LabelEncoder()

df["gender"]= le.fit_transform(df["Gender"])
df["Subscription Type"] = le.fit_transform(df["Subscription Type"])
df["Contract Length"] = le.fit_transform(df['Contract Length'])

# %% [markdown]
# # Observation
# Machine learning models require numerical input.
# Categorical variables converted into numeric format.

# %%
df["spend_per_month"] = df["Total Spend"] / (df["Tenure"] + 1)

# %% [markdown]
# # Observation
# new feature created to capture customer spending behavior Feature engineering may improve prediction accuracy

# %%
plt.figure(figsize = (10,5))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# Some numerical features contain outliers.
# Tree-based models are generally robust to outliers.

# %%
df.drop("Gender", axis=1, inplace=True)

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %% [markdown]
# # Observation
# Independent and target variables separated successfully.

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Observation
# Features standardized.
# Scaling improves performance of KNN and SVM.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# # Observation
# 80% data used for training.
# 20% data reserved for testing

# %% [markdown]
# # Train All Required Models

# %%
# logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# decision Tree 
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Random forest 
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# SVM
#from sklearn.svm import SVC
##svm = SVC(probability=True)
#svm.fit(X_train,y_train)

# %% [markdown]
# # Model Comparison

# %%
models ={
    "Logistic Regression": lr,
    "Decision Tree": dt,
    "Random Forest": rf,
    "KNN": knn

}

# %%
from sklearn.metrics import accuracy_score
results = []
for name, model in models.items():
    pred = model.predict(X_test)
    acc = accuracy_score(y_test,pred)
    results.append([name,acc])

comparison = pd.DataFrame(
    results,
    columns = ["model","Accuracy"]
)

# %% [markdown]
# # Observation
# Compare performance of all models.
# Select model with highest accuracy.

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
pred = rf.predict(X_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6793
#            1       1.00      1.00      1.00      6082
#
#     accuracy                           1.00     12875
#    macro avg       1.00      1.00      1.00     12875
# weighted avg       1.00      1.00      1.00     12875

# %% [markdown]
# # Observation
# Precision shows correctness of positive predictions.
# Recall measures detection capability.
# F1-score balances precision and recall.

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, pred)

sns.heatmap(cm, annot=True,fmt="d")
plt.show()

# %% [markdown]
# # Observation
# Visual representation of correct and incorrect predictions.
# Helps identify classification errors.

# %%
from sklearn.metrics import roc_curve, auc
y_prob = rf.predict_proba(X_test)[:,1]
fpr,tpr,thresholds = roc_curve(y_test,y_prob)
roc_auc = auc(fpr,tpr)

# %%
plt.plot(fpr,tpr,label=f"AUC={roc_auc:.2f}")
plt.legend()
plt.show()

# %% [markdown]
# # Observation
# Higher AUC indicates better classification performance

# %%
from sklearn.model_selection import GridSearchCV

params = {
    "n_estimators":[100,200],
    "max_depth":[5,10,5],
    "min_samples_split":[2,5]
}

# %%
grid = GridSearchCV(
    RandomForestClassifier(),
    params,
    cv=5
)

grid.fit(X_train,y_train)

grid.best_params_

# %% [markdown]
# # Observation
# GridSearchCV identifies best parameter combination.
# Tuned model expected to outperform default model.

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    rf,
    X_scaled,
    y,
    cv=5
)

print(scores)
print(scores.mean())
# Out:
# [0.99852427 0.99852427 0.9992233  0.99937864 0.99937859]
# 0.9990058155897866

# %% [markdown]
# # Observation
# Consistent scores indicate model stability.
# Cross-validation reduces overfitting risk.

# %%
import joblib

joblib.dump(rf,"best_model.pkl")
# Out:
# ['best_model.pkl']

# %% [markdown]
# # Observation
# Model saved for deployment and future reuse.
